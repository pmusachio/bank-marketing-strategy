# %% [markdown]
# # Bank Marketing Strategy - Feature Engineering
#
# Comparison between raw data and features prepared for modeling.

# %%
from pathlib import Path
import sys
import json

PROJECT_ROOT = Path.cwd().resolve()
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from bank_marketing_strategy.config import load_config
from bank_marketing_strategy.data import load_training_frame, profile_dataframe
from bank_marketing_strategy.features import prepare_features

config = load_config()
config["project"]

# %%
df = load_training_frame(config)
features = prepare_features(df.copy(), config)
print('raw shape:', df.shape)
print('feature shape:', features.shape)
features.head()

# %%
new_columns = sorted(set(features.columns) - set(df.columns))
new_columns[:50], len(new_columns)

# %% [markdown]
# ## Feature rationale
#
# - Preparation of the customer's transactional and financial variables.
# - Search for the number of clusters using internal metrics.
# - Generation of `cluster_assignments.csv` for reading the segments.
