# %% [markdown]
# # 05. Deployment and Consumption - Bank Marketing Strategy
#
# This notebook documents how to turn the analytical result into a consumable delivery.
# Training and the main analyses remain reproducible on Colab; the channels that need to
# stay online should run in a local environment or on a deployment platform.

# %% [markdown]
# ## Delivery Channels
#
# - Batch base in `reports/cluster_assignments.csv`.
# - Streamlit dashboard in `app/streamlit_app.py`.
# - BI layer with Metabase or Power BI connected to a SQL table.
# - Simple cloud architecture with S3, EC2, and RDS/Postgres.

# %% [markdown]
# ## Setup
#
# Before consuming the delivery, run the main pipeline to generate `reports/` and `models/`.

# %%
# Colab or local: generate the analytical output
# !PYTHONPATH=src python -m bank_marketing_strategy.cli train

# Local only: open the dashboard
# !python -m pip install -r requirements-app.txt
# !PYTHONPATH=src streamlit run app/streamlit_app.py

# %% [markdown]
# ## Business Reading
#
# The delivery translates card behavior into actionable segments. The dashboard makes it easy to compare size, average profile, and customers of each group before designing campaigns.
